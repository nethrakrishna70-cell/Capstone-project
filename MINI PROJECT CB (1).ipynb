# %%
class ContactBook:
    def __init__(self):
        self.contacts = {}

    def add_contact(self):
        name = input("Enter name: ")
        phone_number = input("Enter phone number: ")
        self.contacts[name] = phone_number
        print("Contact added successfully!")

    def delete_contact(self):
        name = input("Enter name to delete: ")
        if name in self.contacts:
            del self.contacts[name]
            print("Contact deleted successfully!")
        else:
            print("Contact not found.")

    def search_contact(self):
        name = input("Enter name to search: ")
        if name in self.contacts:
            print(f"Phone number: {self.contacts[name]}")
        else:
            print("Contact not found.")

    def update_contact(self):
        name = input("Enter name to update: ")
        if name in self.contacts:
            phone_number = input("Enter new phone number: ")
            self.contacts[name] = phone_number
            print("Contact updated successfully!")
        else:
            print("Contact not found.")

    def display_contacts(self):
        sorted_contacts = dict(sorted(self.contacts.items()))
        if sorted_contacts:
            print("Contacts:")
            for name, phone_number in sorted_contacts.items():
                print(f"{name}: {phone_number}")
        else:
            print("No contacts found.")

def main():
    contact_book = ContactBook()
    while True:
        print("\nContact Book Menu:")
        print("1. Add Contact")
        print("2. Delete Contact")
        print("3. Search Contact")
        print("4. Update Contact")
        print("5. Display Contacts")
        print("6. Exit")
        choice = input("Enter your choice: ")
        if choice == "1":
            contact_book.add_contact()
        elif choice == "2":
            contact_book.delete_contact()
        elif choice == "3":
            contact_book.search_contact()
        elif choice == "4":
            contact_book.update_contact()
        elif choice == "5":
            contact_book.display_contacts()
        elif choice == "6":
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  1
# Enter name:  NETHRA
# Enter phone number:  5674535621
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  1
# Enter name:  RAMYA
# Enter phone number:  6789543210
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  1
# Enter name:  SHREYA
# Enter phone number:  6654378654
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  RAKSHITHA
# Invalid choice. Please try again.
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  1
# Enter name:  RAKSHITHA
# Enter phone number:  7765432199
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  1
# Enter name:  RITHIKA
# Enter phone number:  8890768894
# Contact added successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  2
# Enter name to delete:  RAKSHITHA
# Contact deleted successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  3
# Enter name to search:  NETHRA
# Phone number: 5674535621
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  4
# Enter name to update:  RAMYA
# Enter new phone number:  9987654326
# Contact updated successfully!
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  5
# Contacts:
# NETHRA: 5674535621
# RAMYA: 9987654326
# RITHIKA: 8890768894
# SHREYA: 6654378654
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  5
# Contacts:
# NETHRA: 5674535621
# RAMYA: 9987654326
# RITHIKA: 8890768894
# SHREYA: 6654378654
#
# Contact Book Menu:
# 1. Add Contact
# 2. Delete Contact
# 3. Search Contact
# 4. Update Contact
# 5. Display Contacts
# 6. Exit
# Enter your choice:  6
